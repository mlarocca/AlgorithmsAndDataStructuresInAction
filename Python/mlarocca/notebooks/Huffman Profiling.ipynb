# %%
# %matplotlib notebook
import pandas as pd
import matplotlib.pyplot as plt

# %%
FILE_NAME = '../tests/data/stats.csv'

# %% [markdown]
# ### Create a DataFrame from the stats csv file

# %%
df = pd.read_csv(FILE_NAME)

# %% [markdown]
# ### Peeks into the data frame

# %%
df.info
# Out:
# <bound method DataFrame.info of       test_case  branching_factor               method_name  total_time  \
# 0          text                 2  _frequency_table_to_heap    0.000016
# 1          text                 2             _heap_to_tree    0.000045
# 2          text                 2                  _heapify    0.000007
# 3          text                 2                       top    0.000040
# 4          text                 2                    insert    0.000016
# 5          text                 2  _frequency_table_to_heap    0.000014
# 6          text                 2             _heap_to_tree    0.000047
# 7          text                 2                  _heapify    0.000006
# 8          text                 2                       top    0.000041
# 9          text                 2                    insert    0.000017
# 10         text                 2  _frequency_table_to_heap    0.000014
# 11         text                 2             _heap_to_tree    0.000046
# 12         text                 2                  _heapify    0.000006
# 13         text                 2                       top    0.000040
# 14         text                 2                    insert    0.000017
# 15         text                 2  _frequency_table_to_heap    0.000014
# 16         text                 2             _heap_to_tree    0.000048
# 17         text                 2                  _heapify    0.000007
# 18         text                 2                       top    0.000062
# 19         text                 2                    insert    0.000018
# 20         text                 2  _frequency_table_to_heap    0.000017
# 21         text                 2             _heap_to_tree    0.000046
# 22         text                 2                  _heapify    0.000007
# 23         text                 2                       top    0.000045
# 24         text                 2                    insert    0.000018
# 25         text                 2  _frequency_table_to_heap    0.000014
# 26         text                 2             _heap_to_tree    0.000046
# 27         text                 2                  _heapify    0.000006
# 28         text                 2                       top    0.000041
# 29         text                 2                    insert    0.000015
# ...         ...               ...                       ...         ...
# 27470     image                 6  _frequency_table_to_heap    0.000069
# 27471     image                 6             _heap_to_tree    0.000248
# 27472     image                 6                  _heapify    0.000015
# 27473     image                 6                       top    0.000237
# 27474     image                 6                    insert    0.000082
# 27475     image                 6  _frequency_table_to_heap    0.000046
# 27476     image                 6             _heap_to_tree    0.000236
# 27477     image                 6                  _heapify    0.000013
# 27478     image                 6                       top    0.000162
# 27479     image                 6                    insert    0.000072
# 27480     image                 6  _frequency_table_to_heap    0.000044
# 27481     image                 6             _heap_to_tree    0.000199
# 27482     image                 6                  _heapify    0.000013
# 27483     image                 6                       top    0.000130
# 27484     image                 6                    insert    0.000051
# 27485     image                 6  _frequency_table_to_heap    0.000045
# 27486     image                 6             _heap_to_tree    0.000203
# 27487     image                 6                  _heapify    0.000014
# 27488     image                 6                       top    0.000175
# 27489     image                 6                    insert    0.000070
# 27490     image                 6  _frequency_table_to_heap    0.000047
# 27491     image                 6             _heap_to_tree    0.000156
# 27492     image                 6                  _heapify    0.000014
# 27493     image                 6                       top    0.000138
# 27494     image                 6                    insert    0.000052
# 27495     image                 6  _frequency_table_to_heap    0.000043
# 27496     image                 6             _heap_to_tree    0.000185
# 27497     image                 6                  _heapify    0.000013
# 27498     image                 6                       top    0.000154
# 27499     image                 6                    insert    0.000051
#
#        cumulative_time
# 0             0.000116
# 1             0.000491
# 2             0.000081
# 3             0.000381
# 4             0.000042
# 5             0.000150
# 6             0.000506
# 7             0.000081
# 8             0.000393
# 9             0.000043
# 10            0.000129
# 11            0.000510
# 12            0.000098
# 13            0.000402
# 14            0.000041
# 15            0.000127
# 16            0.000587
# 17            0.000095
# 18            0.000461
# 19            0.000045
# 20            0.000121
# 21            0.000594
# 22            0.000085
# 23            0.000466
# 24            0.000044
# 25            0.000112
# 26            0.000499
# 27            0.000080
# 28            0.000388
# 29            0.000041
# ...                ...
# 27470         0.000439
# 27471         0.003858
# 27472         0.000273
# 27473         0.003230
# 27474         0.000269
# 27475         0.000329
# 27476         0.002887
# 27477         0.000229
# 27478         0.002403
# 27479         0.000163
# 27480         0.000313
# 27481         0.002421
# 27482         0.000217
# 27483         0.001996
# 27484         0.000130
# 27485         0.000329
# 27486         0.003092
# 27487         0.000228
# 27488         0.002584
# 27489         0.000200
# 27490         0.000332
# 27491         0.002359
# 27492         0.000230
# 27493         0.001984
# 27494         0.000139
# 27495         0.000354
# 27496         0.002695
# 27497         0.000258
# 27498         0.002255
# 27499         0.000156
#
# [27500 rows x 5 columns]>

# %% [markdown]
# ### Retrieve all test cases

# %%
test_cases = df['test_case'].unique()
print(test_cases)
# Out:
# ['text' 'image']

# %% [markdown]
# ## Plot Stats per method, per test case

# %%
def plot_test_case_stats(df: pd.DataFrame, test_case: str):
    df_test_case = df[df['test_case']==test_case]
    method_names = df_test_case['method_name'].unique()
    
    for method_name in method_names:
        plot_method_stats(df_test_case, method_name)

# %%
def plot_method_stats(df: pd.DataFrame, method_name: str, time_field: str = 'total_time'):
    df_method: pd.DataFrame = df[df['method_name']==method_name]
    
    branching_factors = df_method['branching_factor'].unique()
    data = [df_method[df_method['branching_factor']==b][time_field] for b in branching_factors]
    
    fig, axe = plt.subplots()

    axe.set_title(method_name, fontsize=16)
    axe.set_xlabel('branching factor')
    axe.set_ylabel('running time')

    plt.boxplot(data, labels=branching_factors, showfliers=False)
    plt.show()

# %% [markdown]
# ### Text files

# %%
plot_test_case_stats(df, 'text')
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Bitmaps

# %%
plot_test_case_stats(df, 'image')
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
