# %%
# %matplotlib notebook
import pandas as pd
import matplotlib.pyplot as plt

# %%
FILE_NAME = '../tests/data/stats.csv'

# %% [markdown]
# ### Create a DataFrame from the stats csv file

# %%
df = pd.read_csv(FILE_NAME)

# %% [markdown]
# ### Peeks into the data frame

# %%
df.info
# Out:
# <bound method DataFrame.info of       test_case  branching_factor              method_name      time
# 0          text                 2  frequency_table_to_heap  0.000249
# 1          text                 2             heap_to_tree  0.000763
# 2          text                 2                 _heapify  0.000176
# 3          text                 2  frequency_table_to_heap  0.000200
# 4          text                 2             heap_to_tree  0.000661
# 5          text                 2                 _heapify  0.000108
# 6          text                 2  frequency_table_to_heap  0.000237
# 7          text                 2             heap_to_tree  0.000819
# 8          text                 2                 _heapify  0.000120
# 9          text                 2  frequency_table_to_heap  0.000107
# 10         text                 2             heap_to_tree  0.000481
# 11         text                 2                 _heapify  0.000076
# 12         text                 2  frequency_table_to_heap  0.000109
# 13         text                 2             heap_to_tree  0.000486
# 14         text                 2                 _heapify  0.000078
# 15         text                 2  frequency_table_to_heap  0.000148
# 16         text                 2             heap_to_tree  0.000496
# 17         text                 2                 _heapify  0.000093
# 18         text                 2  frequency_table_to_heap  0.000156
# 19         text                 2             heap_to_tree  0.000688
# 20         text                 2                 _heapify  0.000112
# 21         text                 2  frequency_table_to_heap  0.000107
# 22         text                 2             heap_to_tree  0.000521
# 23         text                 2                 _heapify  0.000077
# 24         text                 2  frequency_table_to_heap  0.000122
# 25         text                 2             heap_to_tree  0.000488
# 26         text                 2                 _heapify  0.000090
# 27         text                 2  frequency_table_to_heap  0.000184
# 28         text                 2             heap_to_tree  0.000594
# 29         text                 2                 _heapify  0.000152
# ...         ...               ...                      ...       ...
# 16470     image                 6  frequency_table_to_heap  0.000578
# 16471     image                 6             heap_to_tree  0.003068
# 16472     image                 6                 _heapify  0.000393
# 16473     image                 6  frequency_table_to_heap  0.000349
# 16474     image                 6             heap_to_tree  0.003850
# 16475     image                 6                 _heapify  0.000244
# 16476     image                 6  frequency_table_to_heap  0.000349
# 16477     image                 6             heap_to_tree  0.002454
# 16478     image                 6                 _heapify  0.000243
# 16479     image                 6  frequency_table_to_heap  0.000451
# 16480     image                 6             heap_to_tree  0.002676
# 16481     image                 6                 _heapify  0.000329
# 16482     image                 6  frequency_table_to_heap  0.000336
# 16483     image                 6             heap_to_tree  0.002561
# 16484     image                 6                 _heapify  0.000236
# 16485     image                 6  frequency_table_to_heap  0.000336
# 16486     image                 6             heap_to_tree  0.002400
# 16487     image                 6                 _heapify  0.000232
# 16488     image                 6  frequency_table_to_heap  0.000817
# 16489     image                 6             heap_to_tree  0.004114
# 16490     image                 6                 _heapify  0.000620
# 16491     image                 6  frequency_table_to_heap  0.000472
# 16492     image                 6             heap_to_tree  0.002573
# 16493     image                 6                 _heapify  0.000354
# 16494     image                 6  frequency_table_to_heap  0.000341
# 16495     image                 6             heap_to_tree  0.002397
# 16496     image                 6                 _heapify  0.000238
# 16497     image                 6  frequency_table_to_heap  0.000351
# 16498     image                 6             heap_to_tree  0.002412
# 16499     image                 6                 _heapify  0.000244
#
# [16500 rows x 4 columns]>

# %% [markdown]
# ### Retrieve all test cases

# %%
test_cases = df['test_case'].unique()
print(test_cases)
# Out:
# ['text' 'image']

# %% [markdown]
# ## Plot Stats per method, per test case

# %%
def plot_test_case_stats(df: pd.DataFrame, test_case: str):
    df_test_case = df[df['test_case']==test_case]
    method_names = df_test_case['method_name'].unique()
    
    for method_name in method_names:
        plot_method_stats(df_test_case, method_name)

# %%
def plot_method_stats(df: pd.DataFrame, method_name: str, time_field: str = 'total_time'):
    df_method: pd.DataFrame = df[df['method_name']==method_name]
    
    branching_factors = df_method['branching_factor'].unique()
    data = [df_method[df_method['branching_factor']==b][time_field] for b in branching_factors]
    
    fig, axe = plt.subplots()

    axe.set_title(method_name, fontsize=16)
    axe.set_xlabel('branching factor')
    axe.set_ylabel('running time')

    plt.boxplot(data, labels=branching_factors, showfliers=False)
    plt.show()

# %% [markdown]
# ### Text files

# %%
plot_test_case_stats(df, 'text')
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Bitmaps

# %%
plot_test_case_stats(df, 'image')
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
